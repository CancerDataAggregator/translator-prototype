# %%
# Authenticate first: https://cloud.google.com/docs/authentication/getting-started

import json
from queryt.queryt import Dataset, Condition as C
from google.cloud import bigquery

schema = json.load(open("queryt/schema.json", "r"))["schema"]
client = bigquery.Client()
dataset = Dataset(client=client, table="gdc-bq-sample.gdc_metadata.r24_clinical", schema=schema)

# %%
dataset.columns()
# Out:
# ['adverse_event',
#  'adverse_event_grade',
#  'age_at_diagnosis',
#  'age_at_index',
#  'age_at_onset',
#  'age_is_obfuscated',
#  'aids_risk_factors',
#  'ajcc_clinical_m',
#  'ajcc_clinical_n',
#  'ajcc_clinical_stage',
#  'ajcc_clinical_t',
#  'ajcc_pathologic_m',
#  'ajcc_pathologic_n',
#  'ajcc_pathologic_stage',
#  'ajcc_pathologic_t',
#  'ajcc_staging_system_edition',
#  'alcohol_days_per_week',
#  'alcohol_drinks_per_day',
#  'alcohol_history',
#  'alcohol_intensity',
#  'anaplasia_present',
#  'anaplasia_present_type',
#  'ann_arbor_b_symptoms',
#  'ann_arbor_clinical_stage',
#  'ann_arbor_extranodal_involvement',
#  'ann_arbor_pathologic_stage',
#  'annotations',
#  'asbestos_exposure',
#  'barretts_esophagus_goblet_cells_present',
#  'best_overall_response',
#  'bmi',
#  'body_surface_area',
#  'breslow_thickness',
#  'burkitt_lymphoma_clinical_variant',
#  'case_id',
#  'cause_of_death',
#  'cause_of_death_source',
#  'cause_of_response',
#  'cd4_count',
#  'cdc_hiv_risk_factors',
#  'child_pugh_classification',
#  'cigarettes_per_day',
#  'circumferential_resection_margin',
#  'classification_of_tumor',
#  'coal_dust_exposure',
#  'cog_liver_stage',
#  'cog_neuroblastoma_risk_group',
#  'cog_renal_stage',
#  'cog_rhabdomyosarcoma_risk_group',
#  'comorbidity',
#  'comorbidity_method_of_diagnosis',
#  'consent_type',
#  'country_of_residence_at_enrollment',
#  'created_datetime',
#  'created_datetime',
#  'days_to_adverse_event',
#  'days_to_best_overall_response',
#  'days_to_birth',
#  'days_to_comorbidity',
#  'days_to_consent',
#  'days_to_death',
#  'days_to_diagnosis',
#  'days_to_follow_up',
#  'days_to_imaging',
#  'days_to_last_follow_up',
#  'days_to_last_known_disease_status',
#  'days_to_lost_to_followup',
#  'days_to_progression',
#  'days_to_progression_free',
#  'days_to_recurrence',
#  'dbgap_accession_number',
#  'demographic_id',
#  'diabetes_treatment_type',
#  'diagnosis_id',
#  'disease_response',
#  'disease_type',
#  'disease_type',
#  'dlco_ref_predictive_percent',
#  'ecog_performance_status',
#  'enneking_msts_grade',
#  'enneking_msts_metastasis',
#  'enneking_msts_stage',
#  'enneking_msts_tumor_site',
#  'environmental_tobacco_smoke_exposure',
#  'esophageal_columnar_dysplasia_degree',
#  'esophageal_columnar_metaplasia_present',
#  'ethnicity',
#  'evidence_of_recurrence_type',
#  'exposure_duration',
#  'exposure_id',
#  'exposure_type',
#  'family_history_id',
#  'fev1_fvc_post_bronch_percent',
#  'fev1_fvc_pre_bronch_percent',
#  'fev1_ref_post_bronch_percent',
#  'fev1_ref_pre_bronch_percent',
#  'figo_stage',
#  'figo_staging_edition_year',
#  'first_symptom_prior_to_diagnosis',
#  'follow_up_id',
#  'gastric_esophageal_junction_involvement',
#  'gender',
#  'gleason_grade_group',
#  'gleason_grade_tertiary',
#  'gleason_patterns_percent',
#  'goblet_cells_columnar_mucosa_present',
#  'greatest_tumor_dimension',
#  'gross_tumor_weight',
#  'haart_treatment_indicator',
#  'height',
#  'hepatitis_sustained_virological_response',
#  'hiv_viral_load',
#  'hormonal_contraceptive_use',
#  'hpv_positive_type',
#  'hysterectomy_margins_involved',
#  'hysterectomy_type',
#  'icd_10_code',
#  'igcccg_stage',
#  'imaging_result',
#  'imaging_type',
#  'immunosuppressive_treatment_type',
#  'index_date',
#  'inpc_grade',
#  'inpc_histologic_group',
#  'inrg_stage',
#  'inss_stage',
#  'international_prognostic_index',
#  'irs_group',
#  'irs_stage',
#  'ishak_fibrosis_score',
#  'iss_stage',
#  'karnofsky_performance_status',
#  'largest_extrapelvic_peritoneal_focus',
#  'last_known_disease_status',
#  'laterality',
#  'lost_to_followup',
#  'lymph_node_involved_site',
#  'lymph_nodes_positive',
#  'lymph_nodes_tested',
#  'lymphatic_invasion_present',
#  'margin_distance',
#  'margins_involved_site',
#  'marijuana_use_per_week',
#  'masaoka_stage',
#  'medulloblastoma_molecular_classification',
#  'menopause_status',
#  'metastasis_at_diagnosis',
#  'metastasis_at_diagnosis_site',
#  'method_of_diagnosis',
#  'micropapillary_features',
#  'mitosis_karyorrhexis_index',
#  'mitotic_count',
#  'molecular_tests',
#  'morphology',
#  'nadir_cd4_count',
#  'name',
#  'non_nodal_regional_disease',
#  'non_nodal_tumor_deposits',
#  'occupation_duration_years',
#  'ovarian_specimen_status',
#  'ovarian_surface_involvement',
#  'pack_years_smoked',
#  'pancreatitis_onset_year',
#  'papillary_renal_cell_type',
#  'percent_tumor_invasion',
#  'perineural_invasion_present',
#  'peripancreatic_lymph_nodes_positive',
#  'peripancreatic_lymph_nodes_tested',
#  'peritoneal_fluid_cytological_status',
#  'pregnancy_outcome',
#  'pregnant_at_diagnosis',
#  'premature_at_birth',
#  'primary_diagnosis',
#  'primary_gleason_grade',
#  'primary_site',
#  'primary_site',
#  'prior_malignancy',
#  'prior_treatment',
#  'progression_or_recurrence',
#  'progression_or_recurrence_anatomic_site',
#  'progression_or_recurrence_type',
#  'project_id',
#  'race',
#  'radon_exposure',
#  'recist_targeted_regions_number',
#  'recist_targeted_regions_sum',
#  'reflux_treatment_type',
#  'relationship_age_at_diagnosis',
#  'relationship_gender',
#  'relationship_primary_diagnosis',
#  'relationship_type',
#  'relative_with_cancer_history',
#  'relatives_with_cancer_history_count',
#  'releasable',
#  'released',
#  'residual_disease',
#  'respirable_crystalline_silica_exposure',
#  'risk_factor',
#  'risk_factor_treatment',
#  'scan_tracer_used',
#  'secondary_gleason_grade',
#  'secondhand_smoke_as_child',
#  'site_of_resection_or_biopsy',
#  'smoking_frequency',
#  'state',
#  'state',
#  'submitter_id',
#  'submitter_id',
#  'supratentorial_localization',
#  'synchronous_malignancy',
#  'time_between_waking_and_first_smoke',
#  'tissue_or_organ_of_origin',
#  'tobacco_smoking_onset_year',
#  'tobacco_smoking_quit_year',
#  'tobacco_smoking_status',
#  'tobacco_use_per_day',
#  'transglottic_extension',
#  'treatments',
#  'tumor_confined_to_organ_of_origin',
#  'tumor_depth',
#  'tumor_focality',
#  'tumor_grade',
#  'tumor_largest_dimension_diameter',
#  'tumor_regression_grade',
#  'tumor_stage',
#  'type_of_smoke_exposure',
#  'type_of_tobacco_used',
#  'updated_datetime',
#  'updated_datetime',
#  'vascular_invasion_present',
#  'vascular_invasion_type',
#  'viral_hepatitis_serologies',
#  'vital_status',
#  'weeks_gestation_at_birth',
#  'weight',
#  'weiss_assessment_score',
#  'wilms_tumor_histologic_subtype',
#  'year_of_birth',
#  'year_of_death',
#  'year_of_diagnosis',
#  'years_smoked']

# %% [markdown]
# Rows reference the CDA MVP Query list: https://docs.google.com/spreadsheets/d/1VY_zL7NibJa2lpY5YWwYnPlxfKT_wjZn9I4EI1RRUCU/edit#gid=807012355

# %% [markdown]
# Row 16
#
# Select data from TCGA-OV project, with donors over age 50 with Stage IIIC cancer? Do we need to specify the cancer type?

# %%
columns = ['case_id', 'age_at_index', 'gender', 'race', 'project_id', 'figo_stage']
c1 = C('age_at_index', '>=', 50)
c2 = C('project_id', '=', 'TCGA-OV')
c3 = C('figo_stage', '=', 'Stage IIIC')

print(c1.And(c2).And(c3).sql(columns, dataset))
c1.And(c2).And(c3).as_df(columns, dataset)
# Out:
# SELECT case_id, age_at_index, gender, race, project_id, figo_stage FROM gdc-bq-sample.gdc_metadata.r24_clinical, unnest(demographic), unnest(diagnoses), unnest(project) WHERE (((age_at_index >= 50) AND (project_id = 'TCGA-OV')) AND (figo_stage = 'Stage IIIC'))
#                                   case_id  age_at_index  gender  \
# 0    6d10d4ee-6331-4bba-93bc-a7b64cc0b22a            78  female
# 1    b46263ab-c3ca-4fda-a895-74c7e6e6fe22            70  female
# 2    d1e974e7-dd68-40cc-ad06-2b57d964e5a1            78  female
# 3    31872f6a-d225-4f91-b38d-4505d19e406c            78  female
# 4    25a0a9e6-4f5b-45d8-8f34-abfd31d5ff1b            73  female
# ..                                    ...           ...     ...
# 331  1098441d-fb10-4590-a302-0a7cc2332798            61  female
# 332  c040df8a-9d6d-43bd-911a-17a7b4e1ec74            63  female
# 333  c88502e9-0bc6-47c3-adc4-d98b63c7797b            73  female
# 334  09643c0d-efdb-46b4-94df-018bd6134a88            71  female
# 335  b8023162-5e82-40e6-ad8c-8acf81821f01            72  female
#
#                           race project_id  figo_stage
# 0                        white    TCGA-OV  Stage IIIC
# 1                        white    TCGA-OV  Stage IIIC
# 2                        white    TCGA-OV  Stage IIIC
# 3                        white    TCGA-OV  Stage IIIC
# 4                        white    TCGA-OV  Stage IIIC
# ..                         ...        ...         ...
# 331                      white    TCGA-OV  Stage IIIC
# 332                      white    TCGA-OV  Stage IIIC
# 333                      white    TCGA-OV  Stage IIIC
# 334                      white    TCGA-OV  Stage IIIC
# 335  black or african american    TCGA-OV  Stage IIIC
#
# [336 rows x 6 columns]

# %% [markdown]
# Row 17
#
# Select data from female donors from the TCGA-HNSC project from tissue samples from the tongue and exposure to both smoking and alcohol

# %%
c1 = C('project_id', '=', 'TCGA-HNSC')
c2 = C('gender', '=', 'female')

# %%
dataset.unique_values_for("tissue_or_organ_of_origin")
# Out:
# ['Abdomen, NOS',
#  'Adrenal gland, NOS',
#  'Ampulla of Vater',
#  'Anterior floor of mouth',
#  'Anterior mediastinum',
#  'Anterior wall of bladder',
#  'Anus, NOS',
#  'Aortic body and other paraganglia',
#  'Appendix',
#  'Ascending colon',
#  'Autonomic nervous system, NOS',
#  'Base of tongue, NOS',
#  'Biliary tract, NOS',
#  'Bladder neck',
#  'Bladder, NOS',
#  'Body of pancreas',
#  'Body of stomach',
#  'Bone marrow',
#  'Bone, NOS',
#  'Bones of skull and face and associated joints',
#  'Border of tongue',
#  'Brain stem',
#  'Brain, NOS',
#  'Breast, NOS',
#  'Cardia, NOS',
#  'Cecum',
#  'Cerebellum, NOS',
#  'Cerebrum',
#  'Cervix uteri',
#  'Cheek mucosa',
#  'Choroid',
#  'Ciliary body',
#  'Colon, NOS',
#  'Conjunctiva',
#  'Connective, subcutaneous and other soft tissues of abdomen',
#  'Connective, subcutaneous and other soft tissues of head, face, and neck',
#  'Connective, subcutaneous and other soft tissues of lower limb and hip',
#  'Connective, subcutaneous and other soft tissues of pelvis',
#  'Connective, subcutaneous and other soft tissues of thorax',
#  'Connective, subcutaneous and other soft tissues of trunk, NOS',
#  'Connective, subcutaneous and other soft tissues of upper limb and shoulder',
#  'Connective, subcutaneous and other soft tissues, NOS',
#  'Corpus uteri',
#  'Cortex of adrenal gland',
#  'Descending colon',
#  'Dome of bladder',
#  'Duodenum',
#  'Endocervix',
#  'Endometrium',
#  'Esophagus, NOS',
#  'External upper lip',
#  'Extrahepatic bile duct',
#  'Eye, NOS',
#  'Fallopian tube',
#  'Female genital tract, NOS',
#  'Floor of mouth, NOS',
#  'Frontal lobe',
#  'Fundus of stomach',
#  'Fundus uteri',
#  'Gallbladder',
#  'Gastric antrum',
#  'Gastrointestinal tract, NOS',
#  'Gum, NOS',
#  'Hard palate',
#  'Head of pancreas',
#  'Head, face or neck, NOS',
#  'Heart',
#  'Hematopoietic system, NOS',
#  'Hepatic flexure of colon',
#  'Hypopharynx, NOS',
#  'Intestinal tract, NOS',
#  'Intra-abdominal lymph nodes',
#  'Intrahepatic bile duct',
#  'Intrathoracic lymph nodes',
#  'Isthmus uteri',
#  'Jejunum',
#  'Kidney, NOS',
#  'Larynx, NOS',
#  'Lateral wall of bladder',
#  'Lesser curvature of stomach, NOS',
#  'Lip, NOS',
#  'Liver',
#  'Long bones of lower limb and associated joints',
#  'Lower gum',
#  'Lower lobe, lung',
#  'Lower third of esophagus',
#  'Lower-inner quadrant of breast',
#  'Lower-outer quadrant of breast',
#  'Lung, NOS',
#  'Lymph node, NOS',
#  'Lymph nodes of axilla or arm',
#  'Lymph nodes of head, face and neck',
#  'Lymph nodes of inguinal region or leg',
#  'Main bronchus',
#  'Major salivary gland, NOS',
#  'Mandible',
#  'Mediastinum, NOS',
#  'Medulla of adrenal gland',
#  'Meninges, NOS',
#  'Middle lobe, lung',
#  'Middle third of esophagus',
#  'Mouth, NOS',
#  'Myometrium',
#  'Nasal cavity',
#  'Nasopharynx, NOS',
#  'Nervous system, NOS',
#  'Nipple',
#  'Not Reported',
#  'Occipital lobe',
#  'Orbit, NOS',
#  'Oropharynx, NOS',
#  'Other ill-defined sites',
#  'Ovary',
#  'Overlapping lesion of brain',
#  'Overlapping lesion of breast',
#  'Overlapping lesion of connective, subcutaneous and other soft tissues',
#  'Overlapping lesion of eye and adnexa',
#  'Overlapping lesion of lip, oral cavity and pharynx',
#  'Overlapping lesion of lung',
#  'Overlapping lesion of nasopharynx',
#  'Overlapping lesion of pancreas',
#  'Overlapping lesion of rectum, anus and anal canal',
#  'Overlapping lesion of retroperitoneum and peritoneum',
#  'Palate, NOS',
#  'Pancreas, NOS',
#  'Parietal lobe',
#  'Pelvic lymph nodes',
#  'Pelvis, NOS',
#  'Penis, NOS',
#  'Peripheral nerves and autonomic nervous system of abdomen',
#  'Peripheral nerves and autonomic nervous system of head, face, and neck',
#  'Peripheral nerves and autonomic nervous system of pelvis',
#  'Peripheral nerves and autonomic nervous system of thorax',
#  'Peripheral nerves and autonomic nervous system of trunk, NOS',
#  'Peripheral nerves and autonomic nervous system of upper limb and shoulder',
#  'Peritoneum, NOS',
#  'Pharynx, NOS',
#  'Pineal gland',
#  'Pituitary gland',
#  'Pleura, NOS',
#  'Posterior mediastinum',
#  'Posterior wall of bladder',
#  'Posterior wall of oropharynx',
#  'Prostate gland',
#  'Pylorus',
#  'Rectosigmoid junction',
#  'Rectum, NOS',
#  'Renal pelvis',
#  'Retina',
#  'Retromolar area',
#  'Retroperitoneum',
#  'Rib, sternum, clavicle and associated joints',
#  'Short bones of lower limb and associated joints',
#  'Sigmoid colon',
#  'Skin of lower limb and hip',
#  'Skin of trunk',
#  'Skin, NOS',
#  'Small intestine, NOS',
#  'Specified parts of peritoneum',
#  'Spermatic cord',
#  'Spinal cord',
#  'Spinal meninges',
#  'Splenic flexure of colon',
#  'Stomach, NOS',
#  'Submandibular gland',
#  'Supraglottis',
#  'Tail of pancreas',
#  'Temporal lobe',
#  'Testis, NOS',
#  'Thoracic esophagus',
#  'Thorax, NOS',
#  'Thymus',
#  'Thyroid gland',
#  'Tongue, NOS',
#  'Tonsil, NOS',
#  'Trachea',
#  'Transverse colon',
#  'Trigone of bladder',
#  'Unknown',
#  'Unknown primary site',
#  'Upper Gum',
#  'Upper lobe, lung',
#  'Upper third of esophagus',
#  'Upper-inner quadrant of breast',
#  'Upper-outer quadrant of breast',
#  'Urachus',
#  'Ureter',
#  'Ureteric orifice',
#  'Urethra',
#  'Urinary system, NOS',
#  'Uterus, NOS',
#  'Vagina, NOS',
#  'Ventral surface of tongue, NOS',
#  'Vertebral column',
#  'Vulva, NOS']

# %%
c3 = C('tissue_or_organ_of_origin', '=', 'Tongue, NOS')

# %%
dataset.unique_values_for('alcohol_history')
# Out:
# [None, 'No', 'Not Reported', 'Yes']

# %%
c4 = C('alcohol_history', '=', 'Yes')

# %%
dataset.unique_values_for('tobacco_smoking_status')
# Out:
# [None, 1, 2, 3, 4, 5, 7]

# %%
c5 = C('tobacco_smoking_status', 'IS NOT', None)

# %%
columns = ['case_id', 'gender', 'tissue_or_organ_of_origin', 'alcohol_history', 'tobacco_smoking_status']
q = c1.And(c2).And(c3).And(c4).And(c5)
print(q.sql(columns, dataset))
q.as_df(columns, dataset)
# Out:
# SELECT case_id, gender, tissue_or_organ_of_origin, alcohol_history, tobacco_smoking_status FROM gdc-bq-sample.gdc_metadata.r24_clinical, unnest(exposures), unnest(demographic), unnest(diagnoses), unnest(project) WHERE (((((project_id = 'TCGA-HNSC') AND (gender = 'female')) AND (tissue_or_organ_of_origin = 'Tongue, NOS')) AND (alcohol_history = 'Yes')) AND (tobacco_smoking_status IS NOT NULL))
# Empty DataFrame
# Columns: [case_id, gender, tissue_or_organ_of_origin, alcohol_history, tobacco_smoking_status]
# Index: []

# %% [markdown]
# Apparently GDC does not contain any data for this condition. To show the query works, we can relax the smoking status criterion

# %%
columns = ['case_id', 'gender', 'tissue_or_organ_of_origin', 'alcohol_history', 'tobacco_smoking_status']
q = c1.And(c2).And(c3).And(c4)
print(q.sql(columns, dataset))
q.as_df(columns, dataset)
# Out:
# SELECT case_id, gender, tissue_or_organ_of_origin, alcohol_history, tobacco_smoking_status FROM gdc-bq-sample.gdc_metadata.r24_clinical, unnest(exposures), unnest(demographic), unnest(diagnoses), unnest(project) WHERE ((((project_id = 'TCGA-HNSC') AND (gender = 'female')) AND (tissue_or_organ_of_origin = 'Tongue, NOS')) AND (alcohol_history = 'Yes'))
#                                  case_id  gender tissue_or_organ_of_origin  \
# 0   4bfbce2b-9d0b-4e8a-950f-fd8e0ba3e05a  female               Tongue, NOS
# 1   207c8a26-1a2d-47d9-8db8-a25a7fd8655a  female               Tongue, NOS
# 2   116ad004-929d-4c8d-8eee-883d132e0fe5  female               Tongue, NOS
# 3   31202ace-6480-46db-8e0d-b4c64149e326  female               Tongue, NOS
# 4   0fb3e5ff-54f0-43c5-9322-541bb7825e7f  female               Tongue, NOS
# 5   444e5bfc-d4e5-4b0d-b96d-88ecea8873e9  female               Tongue, NOS
# 6   61d0709c-d148-413b-a7b5-c0c82ed2f32f  female               Tongue, NOS
# 7   ed46cc12-2edd-4c95-9814-54b5b6682fcd  female               Tongue, NOS
# 8   0ca3d25a-22e9-4e40-834b-65f402535005  female               Tongue, NOS
# 9   e1527704-8a97-445f-a5ee-357920cb28f7  female               Tongue, NOS
# 10  f458d21d-1854-4baf-9eb1-79c29b663804  female               Tongue, NOS
# 11  832316ee-08ab-412b-9e4d-8a57ff84bc11  female               Tongue, NOS
# 12  417b357e-c90e-4b63-ae7a-4b782038ffd3  female               Tongue, NOS
# 13  7ed006e8-461f-4664-bfff-55fa6812743c  female               Tongue, NOS
# 14  534f85f2-b9eb-45be-87d5-c3dffd13d541  female               Tongue, NOS
# 15  837bf19d-1e02-4c3d-9e65-8999f0652020  female               Tongue, NOS
# 16  b1b3983d-37d2-4bef-bd17-708e3e600146  female               Tongue, NOS
# 17  2a7b4613-f908-4e78-98ed-857dcd7ed774  female               Tongue, NOS
# 18  53d9a130-4a3a-4491-85cd-9a44415a1632  female               Tongue, NOS
# 19  15e43ee8-3080-4895-84fb-a24ad3a68b97  female               Tongue, NOS
# 20  ebfb8c1b-471f-4acb-a1fe-287e02cadba7  female               Tongue, NOS
# 21  22933e67-5c61-4c13-9772-5adb78785b34  female               Tongue, NOS
# 22  b843df7e-db06-4d29-b00d-6a93effd9191  female               Tongue, NOS
# 23  d3f786a6-5d72-4d6e-85fd-0c6ade9f6e95  female               Tongue, NOS
# 24  eda7df86-a344-4790-88ac-e1391f07f66d  female               Tongue, NOS
#
#    alcohol_history  tobacco_smoking_status
# 0              Yes                     NaN
# 1              Yes                     NaN
# 2              Yes                     NaN
# 3              Yes                     NaN
# 4              Yes                     NaN
# 5              Yes                     NaN
# 6              Yes                     NaN
# 7              Yes                     NaN
# 8              Yes                     NaN
# 9              Yes                     NaN
# 10             Yes                     NaN
# 11             Yes                     NaN
# 12             Yes                     NaN
# 13             Yes                     NaN
# 14             Yes                     NaN
# 15             Yes                     NaN
# 16             Yes                     NaN
# 17             Yes                     NaN
# 18             Yes                     NaN
# 19             Yes                     NaN
# 20             Yes                     NaN
# 21             Yes                     NaN
# 22             Yes                     NaN
# 23             Yes                     NaN
# 24             Yes                     NaN

# %% [markdown]
# Row 13
#
# "Find data sequencing data from samples where the donor is Asian"
#
# **Problem identified**
# 1. Current table does not have links to sequencing data

# %%
dataset.unique_values_for("race")
# Out:
# ['Unknown',
#  'american indian or alaska native',
#  'asian',
#  'black or african american',
#  'native hawaiian or other pacific islander',
#  'not allowed to collect',
#  'not reported',
#  'other',
#  'unknown',
#  'white']

# %%
columns = ['case_id', 'age_at_index', 'gender', 'race', 'project_id']
c1 = C('race', '=', 'asian')
c1.as_df(columns, dataset)
# Out:
#                                    case_id  age_at_index  gender   race  \
# 0     82ba31a6-dd05-4f6f-88d9-8f961822d732           NaN  female  asian
# 1     8569f0ba-0f77-4a53-af49-127604bec479           NaN  female  asian
# 2     954d88e0-e578-41dd-8a49-21ae84abf81b          59.0  female  asian
# 3     5718a50d-332c-4882-8736-2ca8989946dd           NaN    male  asian
# 4     1a2bc1c7-4f05-4aec-90d1-8617ce121ffd       20819.0  female  asian
# ...                                    ...           ...     ...    ...
# 2927  b6c4390a-cc43-40a2-9e0e-3b1aab77d1f2       27759.0  female  asian
# 2928  339222d1-761b-4afd-94cd-cc5828cf5b88       13149.0  female  asian
# 2929  867544e2-2dcc-4e11-b455-5f0065f5a311       14610.0    male  asian
# 2930  0d054fce-14d0-46a6-b818-27bad49ddf38       25202.0    male  asian
# 2931  d1900856-302c-4518-91f6-d69994facc69       30315.0  female  asian
#
#      project_id
# 0       CPTAC-2
# 1       CPTAC-2
# 2       CPTAC-3
# 3       CPTAC-3
# 4     GENIE-MDA
# ...         ...
# 2927  GENIE-MSK
# 2928  GENIE-MSK
# 2929  GENIE-MSK
# 2930  GENIE-MSK
# 2931  GENIE-MSK
#
# [2932 rows x 5 columns]

# %% [markdown]
# Row 8
# "Find data across all species with a diagnosis of "spontaneous mammary carcinoma"
#
# **Problem identified**
# What do we do with repeated column names? In this case it is "disease_type"

# %%
# dataset.unique_values_for("disease_type")

# %%
columns = ['case_id', 'age_at_index', 'gender', 'race', 'project_id']
c1 = C('disease_type', '=', 'Acinar Cell Neoplasms')
# c1.as_df(columns, dataset)  # see problems identified

# %% [markdown]
# Row 11
#
# Researcher would like to identify all lung samples in the repository with the following characteristics:
# o        Sample from primary tumor tissue (not cell line)
# o        Disease = triple negative breast cancer
# o        Subjects – under the age of 50 years – male or female"
#
# **Problem identified**
#
# 1. User issue. I'm not clear how to detect sample type
# 2. User issue. Could not find "tripe negative breast cancer" in disease type value

# %%
columns = ['case_id', 'age_at_index', 'gender', 'race', 'project_id']
c1 = C('age_at_index', '<', 50)
c1.as_df(columns, dataset)
# Out:
#                                    case_id  age_at_index  gender  \
# 0     20bda057-349d-46f7-aeb5-ccf011cb107f            43    male
# 1     3d2aa654-1b5f-4eb4-a1c2-af31f5760069            41    male
# 2     603d2b61-b636-4054-ac95-ab66dabb3b48            21  female
# 3     0ca72ebd-ff33-45b8-a97c-3f1435603d71            30  female
# 4     606dc5b8-7625-42a6-a936-504ef25623a4            44    male
# ...                                    ...           ...     ...
# 2986  bd25db19-92dd-4d8e-8b07-4dba8095cfcb            15    male
# 2987  fcd39a3f-169a-463f-8153-17ebc1b218a8             8  female
# 2988  fcfdb847-5081-4086-8d32-25a281097390             7    male
# 2989  2843599b-b36f-460b-8563-2e022974103f             8    male
# 2990  7824ba74-2279-4833-9eb8-0db056a119e0             7    male
#
#                            race  project_id
# 0                         white     CPTAC-3
# 1                  not reported   TCGA-LUAD
# 2     black or african american    TCGA-GBM
# 3     black or african american    TCGA-GBM
# 4                  not reported   TCGA-ESCA
# ...                         ...         ...
# 2986                      white  CGCI-BLGSP
# 2987                      white  CGCI-BLGSP
# 2988                      white  CGCI-BLGSP
# 2989                      white  CGCI-BLGSP
# 2990                      white  CGCI-BLGSP
#
# [2991 rows x 5 columns]
